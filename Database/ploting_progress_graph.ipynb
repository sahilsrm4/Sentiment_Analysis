# %%
import mysql.connector

# %%
def connect_db():
        conn = mysql.connector.connect(
            host = "localhost",
            user = 'root',
            password = '9068$$$$pppP',
            database = "feel_fetch"
        )
        return conn

# %%
import datetime

# %%
conn = connect_db()

cursor = conn.cursor()

user_id = 3
query = "select * from video_analysis where user_id = %s"
cursor.execute(query,(user_id,))
result = cursor.fetchall()

score = []
time = []
for row in result:
    score.append(row[3])
    time.append(row[4])
print(score)
print(time)
# Out:
# [45.0, 56.0, 65.0, 78.0, 50.0, 59.0, 80.0, 60.0]
# [datetime.datetime(2025, 6, 3, 12, 9, 53), datetime.datetime(2025, 6, 3, 12, 10, 12), datetime.datetime(2025, 6, 3, 12, 10, 30), datetime.datetime(2025, 6, 3, 12, 10, 39), datetime.datetime(2025, 6, 3, 12, 10, 50), datetime.datetime(2025, 6, 3, 12, 10, 56), datetime.datetime(2025, 6, 3, 12, 11, 1), datetime.datetime(2025, 6, 3, 12, 11, 8)]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,4))
plt.plot(time,score)
